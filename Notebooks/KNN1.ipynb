# %% [markdown]
# # Willkommen im Notebook KNN1 zum Thema "Künstliche Neuronale Netze"!
#
# Dies ist ein interaktives Jupyter-Notebook, in dem es ausführbare Zellen mit Python-Code gibt.
#
# Klicken Sie in der untenstehenden Zelle auf den "play"-Button (oben links), um die nötigen Funktionen zu laden.

# %%
import numpy as np
import matplotlib.pyplot as plt
# !git clone "https://github.com/Sammy-Jankins/KNN_Lernen.git" "KNN_Lernen" 2> /dev/null
from KNN_Lernen import KNN_Funktionen as knn

# %% [markdown]
# # Graph der KNN-Funktion
#
# Verändern Sie unten die Daten für Ihr KNN und klicken Sie auf 'play', um den Graph der KNN-Funktion zu plotten. (Siehe Frage 3.2.1.)
#
# Das KNN besitzt ein Input-Neuron (mit oder ohne Bias), ein Output-Neuron und eine versteckte Schicht mit variabler Anzahl an Neuronen.

# %%
##### Verändern Sie die folgenden Parameter:

Anzahl_verborgene_Neuronen = 2
Bias = "Nein" # mögliche Werte: "Ja", "Nein"
Aktivierungsfunktion = "ReLU" # mögliche Werte: "ReLU", "Linear", "Sigmoid"
Input_Gewichte = [-1,2]
Bias_Gewichte = [0,-2]
Output_Gewichte = [1,2]

##########


Daten = [Anzahl_verborgene_Neuronen, Bias, Aktivierungsfunktion, Input_Gewichte, Bias_Gewichte, Output_Gewichte]
Plot_linke_Grenze = -1
Plot_rechte_Grenze = 2
knn.Graph_KNN_Funktion(Daten, Plot_linke_Grenze, Plot_rechte_Grenze)

# %% [markdown]
# # Approximieren der Exponentialfunktion
#
# Versuchen Sie nun, ein KNN zu konstruieren, welches die Exponentialfunktion möglichst gut approximiert (mit Fehler < 2, siehe Frage 3.2.2.)

# %%
##### Verändern Sie die folgenden Parameter:

Anzahl_verborgene_Neuronen = 4
Bias = "Ja" # mögliche Werte: "Ja", "Nein"
Aktivierungsfunktion = "ReLU" # mögliche Werte: "ReLU", "Linear", "Sigmoid"
Input_Gewichte = [0,1,-2,3]
Bias_Gewichte = [0,1,2,1]
Output_Gewichte = [1,1,1,1]

##########


Daten = [Anzahl_verborgene_Neuronen, Bias, Aktivierungsfunktion, Input_Gewichte, Bias_Gewichte, Output_Gewichte]
knn.Graph_KNN_Funktion_Expo(Daten)
# Out:
# Der Approximationsfehler beträgt: 7.9502
# Leider ist der Fehler größer als 2 :(
